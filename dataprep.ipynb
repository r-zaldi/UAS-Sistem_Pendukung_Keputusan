# %%
import csv

file_path = 'vehicle_emission_dataset.csv'
prepared_file_path = 'vehicle_dataset_clean.csv'

kolom = [
    'Vehicle Type', 
    'Fuel Type', 
    'Engine Size', 
    'Age of Vehicle', 
    'Mileage',
    'Emission Level'
]

vehicle_type_map = {
    'Motorcycle': 1,
    'Car': 2,
    'Bus': 3,
    'Truck': 4
}

fuel_type_map = {
    'Electric': 1,
    'Hybrid': 2,
    'Petrol': 3,
    'Diesel': 4
}

data = []
with open(file_path, 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        data.append({key: row[key] for key in kolom})

data = [row for row in data if all(row.values())]

data
# Out:
# [{'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.747608618006285',
#   'Age of Vehicle': '22',
#   'Mileage': '291288',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.743714393331564',
#   'Age of Vehicle': '3',
#   'Mileage': '188398',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.606368497419306',
#   'Age of Vehicle': '17',
#   'Mileage': '281451',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.91302411782459',
#   'Age of Vehicle': '4',
#   'Mileage': '151321',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.6112969303006701',
#   'Age of Vehicle': '15',
#   'Mileage': '91810',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.6111715057482539',
#   'Age of Vehicle': '13',
#   'Mileage': '72131',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.1020347832746373',
#   'Age of Vehicle': '26',
#   'Mileage': '169449',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.304115958029663',
#   'Age of Vehicle': '26',
#   'Mileage': '296695',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.925798061064686',
#   'Age of Vehicle': '18',
#   'Mileage': '90214',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.481977404539436',
#   'Age of Vehicle': '13',
#   'Mileage': '38599',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '0.9070393703381727',
#   'Age of Vehicle': '8',
#   'Mileage': '229417',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.843531231242371',
#   'Age of Vehicle': '5',
#   'Mileage': '109490',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.128701732162193',
#   'Age of Vehicle': '16',
#   'Mileage': '22593',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.9041633755270362',
#   'Age of Vehicle': '18',
#   'Mileage': '225472',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.7454898294769232',
#   'Age of Vehicle': '11',
#   'Mileage': '109865',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.7537034512378558',
#   'Age of Vehicle': '3',
#   'Mileage': '173708',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.3820596633895965',
#   'Age of Vehicle': '15',
#   'Mileage': '187031',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.528733444487637',
#   'Age of Vehicle': '24',
#   'Mileage': '216989',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.046114096939002',
#   'Age of Vehicle': '10',
#   'Mileage': '229701',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.314391529029818',
#   'Age of Vehicle': '21',
#   'Mileage': '132192',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.9816350525563733',
#   'Age of Vehicle': '3',
#   'Mileage': '43638',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.5253680753906176',
#   'Age of Vehicle': '16',
#   'Mileage': '170134',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.3191521723831343',
#   'Age of Vehicle': '7',
#   'Mileage': '267337',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.705081585127197',
#   'Age of Vehicle': '13',
#   'Mileage': '15213',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.1715639179285873',
#   'Age of Vehicle': '26',
#   'Mileage': '254286',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.8829149992436705',
#   'Age of Vehicle': '1',
#   'Mileage': '244987',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.8383036672234707',
#   'Age of Vehicle': '10',
#   'Mileage': '215031',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.4740190797507804',
#   'Age of Vehicle': '10',
#   'Mileage': '148259',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.880555758082621',
#   'Age of Vehicle': '23',
#   'Mileage': '141112',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.0415421461439882',
#   'Age of Vehicle': '21',
#   'Mileage': '197374',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.95923322988748',
#   'Age of Vehicle': '23',
#   'Mileage': '29949',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.686725443173916',
#   'Age of Vehicle': '5',
#   'Mileage': '243072',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.1382682835234537',
#   'Age of Vehicle': '20',
#   'Mileage': '248066',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.734204793717333',
#   'Age of Vehicle': '20',
#   'Mileage': '214480',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.8212865719877085',
#   'Age of Vehicle': '13',
#   'Mileage': '208366',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.003666210205598',
#   'Age of Vehicle': '29',
#   'Mileage': '287556',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.3839915997015275',
#   'Age of Vehicle': '9',
#   'Mileage': '145384',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.3078949928331962',
#   'Age of Vehicle': '25',
#   'Mileage': '142876',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.358011737863216',
#   'Age of Vehicle': '26',
#   'Mileage': '185058',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.0887929674459267',
#   'Age of Vehicle': '7',
#   'Mileage': '46545',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.43459882119285',
#   'Age of Vehicle': '6',
#   'Mileage': '161071',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.374919932578605',
#   'Age of Vehicle': '7',
#   'Mileage': '3768',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '0.9788203097991357',
#   'Age of Vehicle': '27',
#   'Mileage': '263648',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.528466090809666',
#   'Age of Vehicle': '7',
#   'Mileage': '8002',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.145655904320088',
#   'Age of Vehicle': '22',
#   'Mileage': '75427',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.245115878640706',
#   'Age of Vehicle': '1',
#   'Mileage': '13898',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.420897595664937',
#   'Age of Vehicle': '26',
#   'Mileage': '80800',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.504353710124616',
#   'Age of Vehicle': '15',
#   'Mileage': '214299',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.6428934525850547',
#   'Age of Vehicle': '8',
#   'Mileage': '126718',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.7612431687327406',
#   'Age of Vehicle': '12',
#   'Mileage': '33743',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.841840064375704',
#   'Age of Vehicle': '22',
#   'Mileage': '209610',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.830690681477796',
#   'Age of Vehicle': '11',
#   'Mileage': '243589',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.6853944961337834',
#   'Age of Vehicle': '26',
#   'Mileage': '174458',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.453102222223774',
#   'Age of Vehicle': '21',
#   'Mileage': '130864',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.909079889817643',
#   'Age of Vehicle': '24',
#   'Mileage': '152395',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.593746022120207',
#   'Age of Vehicle': '28',
#   'Mileage': '172391',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.2601610106699814',
#   'Age of Vehicle': '16',
#   'Mileage': '16868',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.8191108845795552',
#   'Age of Vehicle': '26',
#   'Mileage': '230804',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.035181902334798',
#   'Age of Vehicle': '1',
#   'Mileage': '264224',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.4917177199689746',
#   'Age of Vehicle': '12',
#   'Mileage': '144848',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.821121906385306',
#   'Age of Vehicle': '0',
#   'Mileage': '197303',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.2110149652242588',
#   'Age of Vehicle': '25',
#   'Mileage': '184884',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.109435047590033',
#   'Age of Vehicle': '27',
#   'Mileage': '63271',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.6551172988066645',
#   'Age of Vehicle': '18',
#   'Mileage': '77585',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.26085945037438',
#   'Age of Vehicle': '10',
#   'Mileage': '124147',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.6220196324228926',
#   'Age of Vehicle': '4',
#   'Mileage': '15628',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.532805969868766',
#   'Age of Vehicle': '0',
#   'Mileage': '259517',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.971424299921006',
#   'Age of Vehicle': '19',
#   'Mileage': '139337',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.1876633471348084',
#   'Age of Vehicle': '29',
#   'Mileage': '274604',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.93181207032269',
#   'Age of Vehicle': '12',
#   'Mileage': '259970',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.815672800342618',
#   'Age of Vehicle': '7',
#   'Mileage': '3477',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.8333215439776966',
#   'Age of Vehicle': '5',
#   'Mileage': '264346',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '0.8287150090427325',
#   'Age of Vehicle': '28',
#   'Mileage': '113846',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.040399427965138',
#   'Age of Vehicle': '16',
#   'Mileage': '244000',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.475658188007609',
#   'Age of Vehicle': '11',
#   'Mileage': '273994',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.5908372738131344',
#   'Age of Vehicle': '0',
#   'Mileage': '235693',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.810605802766918',
#   'Age of Vehicle': '2',
#   'Mileage': '133878',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.18503218901727',
#   'Age of Vehicle': '13',
#   'Mileage': '262329',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.664021788430218',
#   'Age of Vehicle': '25',
#   'Mileage': '24718',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.4025191095306746',
#   'Age of Vehicle': '7',
#   'Mileage': '187274',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.288137814553086',
#   'Age of Vehicle': '10',
#   'Mileage': '156287',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.0411502595033015',
#   'Age of Vehicle': '26',
#   'Mileage': '280602',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.520669729233776',
#   'Age of Vehicle': '13',
#   'Mileage': '130293',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.1305034214873229',
#   'Age of Vehicle': '7',
#   'Mileage': '147078',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.417108072921444',
#   'Age of Vehicle': '28',
#   'Mileage': '225152',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.490953274539085',
#   'Age of Vehicle': '2',
#   'Mileage': '76820',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.593952127357933',
#   'Age of Vehicle': '6',
#   'Mileage': '225751',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.1152988510471085',
#   'Age of Vehicle': '27',
#   'Mileage': '81234',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.413506261396898',
#   'Age of Vehicle': '18',
#   'Mileage': '129282',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.255517610842136',
#   'Age of Vehicle': '3',
#   'Mileage': '271246',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.4218900788791689',
#   'Age of Vehicle': '24',
#   'Mileage': '234501',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.508872893559574',
#   'Age of Vehicle': '15',
#   'Mileage': '126328',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.756082252807867',
#   'Age of Vehicle': '12',
#   'Mileage': '84079',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.718641427361381',
#   'Age of Vehicle': '19',
#   'Mileage': '94437',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.809029335763717',
#   'Age of Vehicle': '18',
#   'Mileage': '79570',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.367737101094832',
#   'Age of Vehicle': '4',
#   'Mileage': '92656',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.5182107127863693',
#   'Age of Vehicle': '22',
#   'Mileage': '197937',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.0232132954644584',
#   'Age of Vehicle': '4',
#   'Mileage': '172492',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '0.932179459069295',
#   'Age of Vehicle': '19',
#   'Mileage': '156454',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.3610354203651833',
#   'Age of Vehicle': '23',
#   'Mileage': '38795',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '0.9634317655710182',
#   'Age of Vehicle': '3',
#   'Mileage': '51425',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.109334138571659',
#   'Age of Vehicle': '1',
#   'Mileage': '57402',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.4346511015968986',
#   'Age of Vehicle': '25',
#   'Mileage': '207275',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.444567594056455',
#   'Age of Vehicle': '12',
#   'Mileage': '238723',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.519345664415684',
#   'Age of Vehicle': '29',
#   'Mileage': '203567',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.09631959157415',
#   'Age of Vehicle': '15',
#   'Mileage': '95117',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.9339911997852743',
#   'Age of Vehicle': '21',
#   'Mileage': '261712',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.7288659204238535',
#   'Age of Vehicle': '1',
#   'Mileage': '209125',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.989750460556437',
#   'Age of Vehicle': '18',
#   'Mileage': '187350',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.2002955311097236',
#   'Age of Vehicle': '16',
#   'Mileage': '30568',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.306707555151594',
#   'Age of Vehicle': '4',
#   'Mileage': '271056',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.638350693720823',
#   'Age of Vehicle': '24',
#   'Mileage': '163599',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.63442779218138',
#   'Age of Vehicle': '17',
#   'Mileage': '230066',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.002225973734968',
#   'Age of Vehicle': '27',
#   'Mileage': '253007',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.093699533854203',
#   'Age of Vehicle': '22',
#   'Mileage': '2355',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.3315950689761324',
#   'Age of Vehicle': '20',
#   'Mileage': '96429',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.979094799875395',
#   'Age of Vehicle': '17',
#   'Mileage': '185805',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.7701643062073864',
#   'Age of Vehicle': '7',
#   'Mileage': '111151',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.441306792147884',
#   'Age of Vehicle': '26',
#   'Mileage': '280232',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.6045796579613842',
#   'Age of Vehicle': '14',
#   'Mileage': '175477',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.998688806853125',
#   'Age of Vehicle': '12',
#   'Mileage': '61788',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.459674759602165',
#   'Age of Vehicle': '12',
#   'Mileage': '51529',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.4536180698536922',
#   'Age of Vehicle': '15',
#   'Mileage': '112833',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.3722700075439191',
#   'Age of Vehicle': '21',
#   'Mileage': '103578',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.985262845218097',
#   'Age of Vehicle': '19',
#   'Mileage': '183455',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.020960500856533',
#   'Age of Vehicle': '12',
#   'Mileage': '39177',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.053676782796964',
#   'Age of Vehicle': '19',
#   'Mileage': '116903',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.275799032932986',
#   'Age of Vehicle': '1',
#   'Mileage': '39056',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '0.8361510787621917',
#   'Age of Vehicle': '2',
#   'Mileage': '66421',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.4558859734033422',
#   'Age of Vehicle': '14',
#   'Mileage': '164704',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.9705372163736508',
#   'Age of Vehicle': '22',
#   'Mileage': '208294',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.9549606144477973',
#   'Age of Vehicle': '18',
#   'Mileage': '68590',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.4232999101351507',
#   'Age of Vehicle': '12',
#   'Mileage': '271121',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.5555988912988656',
#   'Age of Vehicle': '4',
#   'Mileage': '283644',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.7031304603451',
#   'Age of Vehicle': '25',
#   'Mileage': '10011',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.4806552465079275',
#   'Age of Vehicle': '21',
#   'Mileage': '179111',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.4977112330655036',
#   'Age of Vehicle': '5',
#   'Mileage': '814',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.4556985862549245',
#   'Age of Vehicle': '13',
#   'Mileage': '282294',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.6908739323723285',
#   'Age of Vehicle': '3',
#   'Mileage': '3825',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.853266830148995',
#   'Age of Vehicle': '21',
#   'Mileage': '50368',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.804725933698978',
#   'Age of Vehicle': '18',
#   'Mileage': '75535',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.109267938291894',
#   'Age of Vehicle': '22',
#   'Mileage': '86390',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.3856922306404043',
#   'Age of Vehicle': '6',
#   'Mileage': '223923',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.364567211047202',
#   'Age of Vehicle': '3',
#   'Mileage': '105076',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.2811705707628316',
#   'Age of Vehicle': '1',
#   'Mileage': '206089',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '0.9918121262435706',
#   'Age of Vehicle': '26',
#   'Mileage': '179577',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.969734536695464',
#   'Age of Vehicle': '6',
#   'Mileage': '253477',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.4139309207900803',
#   'Age of Vehicle': '2',
#   'Mileage': '57899',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.0676895064999448',
#   'Age of Vehicle': '14',
#   'Mileage': '213854',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.24896161403038',
#   'Age of Vehicle': '0',
#   'Mileage': '284745',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.5229826070265995',
#   'Age of Vehicle': '1',
#   'Mileage': '141749',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.0457218314682564',
#   'Age of Vehicle': '9',
#   'Mileage': '260321',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.55345333487436',
#   'Age of Vehicle': '15',
#   'Mileage': '218930',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.345154353443328',
#   'Age of Vehicle': '24',
#   'Mileage': '123355',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.9253823613751235',
#   'Age of Vehicle': '27',
#   'Mileage': '164364',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.058687411859802',
#   'Age of Vehicle': '14',
#   'Mileage': '128424',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.295104846510569',
#   'Age of Vehicle': '23',
#   'Mileage': '125451',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.760421999709331',
#   'Age of Vehicle': '14',
#   'Mileage': '204775',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.0357152287604783',
#   'Age of Vehicle': '13',
#   'Mileage': '147256',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.58672501278167',
#   'Age of Vehicle': '21',
#   'Mileage': '220408',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.712472290140117',
#   'Age of Vehicle': '13',
#   'Mileage': '61377',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.087990319086614',
#   'Age of Vehicle': '5',
#   'Mileage': '45161',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.094354495956653',
#   'Age of Vehicle': '13',
#   'Mileage': '166078',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.586028357188744',
#   'Age of Vehicle': '16',
#   'Mileage': '148616',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.2695068042829232',
#   'Age of Vehicle': '17',
#   'Mileage': '12987',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.1435729770640375',
#   'Age of Vehicle': '19',
#   'Mileage': '5239',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.4680563378530262',
#   'Age of Vehicle': '18',
#   'Mileage': '44785',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.7698962540792422',
#   'Age of Vehicle': '29',
#   'Mileage': '23358',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.0120307360847725',
#   'Age of Vehicle': '16',
#   'Mileage': '187522',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.8726433045788573',
#   'Age of Vehicle': '15',
#   'Mileage': '219592',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.323334681579869',
#   'Age of Vehicle': '7',
#   'Mileage': '159500',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '0.886256710424852',
#   'Age of Vehicle': '6',
#   'Mileage': '9096',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.4628839031562615',
#   'Age of Vehicle': '19',
#   'Mileage': '47582',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.9777780310292774',
#   'Age of Vehicle': '27',
#   'Mileage': '188467',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.154898510129139',
#   'Age of Vehicle': '11',
#   'Mileage': '101494',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.7067054308259557',
#   'Age of Vehicle': '8',
#   'Mileage': '263431',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.392876238132823',
#   'Age of Vehicle': '26',
#   'Mileage': '185582',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.8110238007627943',
#   'Age of Vehicle': '13',
#   'Mileage': '23902',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.67099594143102',
#   'Age of Vehicle': '19',
#   'Mileage': '132844',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.515108909559165',
#   'Age of Vehicle': '0',
#   'Mileage': '184126',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.5735450254613443',
#   'Age of Vehicle': '9',
#   'Mileage': '126800',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.3900623104510632',
#   'Age of Vehicle': '16',
#   'Mileage': '235576',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.608406815048526',
#   'Age of Vehicle': '16',
#   'Mileage': '7213',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.362164637581102',
#   'Age of Vehicle': '16',
#   'Mileage': '277085',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.1412964641188093',
#   'Age of Vehicle': '3',
#   'Mileage': '26855',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.2319170393777314',
#   'Age of Vehicle': '16',
#   'Mileage': '1046',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.049555441046322',
#   'Age of Vehicle': '17',
#   'Mileage': '277053',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.6870442203172047',
#   'Age of Vehicle': '19',
#   'Mileage': '210186',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.5541830074512335',
#   'Age of Vehicle': '22',
#   'Mileage': '94135',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.057631912682349',
#   'Age of Vehicle': '1',
#   'Mileage': '71255',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.2841343925906759',
#   'Age of Vehicle': '7',
#   'Mileage': '212568',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.4655219413572995',
#   'Age of Vehicle': '12',
#   'Mileage': '220214',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.482173897249318',
#   'Age of Vehicle': '22',
#   'Mileage': '246936',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.092127577820993',
#   'Age of Vehicle': '24',
#   'Mileage': '235787',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.5629549134532437',
#   'Age of Vehicle': '29',
#   'Mileage': '272496',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.6158897879858367',
#   'Age of Vehicle': '21',
#   'Mileage': '271367',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.574969530125245',
#   'Age of Vehicle': '19',
#   'Mileage': '249048',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.464973351753401',
#   'Age of Vehicle': '21',
#   'Mileage': '50044',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.41284940617861',
#   'Age of Vehicle': '14',
#   'Mileage': '85000',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.855352838459644',
#   'Age of Vehicle': '19',
#   'Mileage': '203074',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.138564560002297',
#   'Age of Vehicle': '22',
#   'Mileage': '293172',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.237527817974254',
#   'Age of Vehicle': '8',
#   'Mileage': '57965',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.6404693132919916',
#   'Age of Vehicle': '2',
#   'Mileage': '234466',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.472481780340812',
#   'Age of Vehicle': '2',
#   'Mileage': '69776',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.953431110229868',
#   'Age of Vehicle': '1',
#   'Mileage': '293603',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '0.8478246684064742',
#   'Age of Vehicle': '0',
#   'Mileage': '90932',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.327652022903367',
#   'Age of Vehicle': '13',
#   'Mileage': '155761',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.2502091993618905',
#   'Age of Vehicle': '16',
#   'Mileage': '176251',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '0.8263202360003372',
#   'Age of Vehicle': '12',
#   'Mileage': '114773',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.636201867370993',
#   'Age of Vehicle': '18',
#   'Mileage': '212678',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.653415704706248',
#   'Age of Vehicle': '29',
#   'Mileage': '212243',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.397855028002005',
#   'Age of Vehicle': '22',
#   'Mileage': '181027',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.190198549413523',
#   'Age of Vehicle': '14',
#   'Mileage': '80260',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.966200409194911',
#   'Age of Vehicle': '26',
#   'Mileage': '55871',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.503331951007187',
#   'Age of Vehicle': '24',
#   'Mileage': '191750',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.0336952549833605',
#   'Age of Vehicle': '13',
#   'Mileage': '120773',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.492078430428192',
#   'Age of Vehicle': '1',
#   'Mileage': '60693',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.681755306613725',
#   'Age of Vehicle': '6',
#   'Mileage': '293577',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.178091075045517',
#   'Age of Vehicle': '16',
#   'Mileage': '74797',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.215961734569725',
#   'Age of Vehicle': '17',
#   'Mileage': '210087',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.219587039961786',
#   'Age of Vehicle': '5',
#   'Mileage': '277948',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.755204737344452',
#   'Age of Vehicle': '26',
#   'Mileage': '223853',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.287108792706081',
#   'Age of Vehicle': '20',
#   'Mileage': '191187',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.7121221759090544',
#   'Age of Vehicle': '7',
#   'Mileage': '78363',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.1790523119449725',
#   'Age of Vehicle': '27',
#   'Mileage': '107904',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.0687461455712346',
#   'Age of Vehicle': '26',
#   'Mileage': '114952',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.859654884712717',
#   'Age of Vehicle': '1',
#   'Mileage': '19477',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.8441081682671543',
#   'Age of Vehicle': '0',
#   'Mileage': '278271',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.438642086920989',
#   'Age of Vehicle': '15',
#   'Mileage': '217790',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.081920855185767',
#   'Age of Vehicle': '6',
#   'Mileage': '26049',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.933018778416572',
#   'Age of Vehicle': '21',
#   'Mileage': '12473',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.4137128841469995',
#   'Age of Vehicle': '23',
#   'Mileage': '213317',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.799900200057068',
#   'Age of Vehicle': '10',
#   'Mileage': '230582',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.361092007858092',
#   'Age of Vehicle': '14',
#   'Mileage': '13714',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.8152635365498315',
#   'Age of Vehicle': '12',
#   'Mileage': '212875',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.556750999359828',
#   'Age of Vehicle': '29',
#   'Mileage': '96988',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.2600162846924503',
#   'Age of Vehicle': '23',
#   'Mileage': '267280',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '0.92644302544356',
#   'Age of Vehicle': '1',
#   'Mileage': '98115',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.156455938717273',
#   'Age of Vehicle': '13',
#   'Mileage': '31516',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.7209755329166545',
#   'Age of Vehicle': '23',
#   'Mileage': '45099',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.690384638635154',
#   'Age of Vehicle': '5',
#   'Mileage': '13188',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.760428600413454',
#   'Age of Vehicle': '8',
#   'Mileage': '237445',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.557294829146333',
#   'Age of Vehicle': '27',
#   'Mileage': '111073',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.724825241328311',
#   'Age of Vehicle': '6',
#   'Mileage': '5560',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '0.8803744059501106',
#   'Age of Vehicle': '17',
#   'Mileage': '108763',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.627256525456172',
#   'Age of Vehicle': '23',
#   'Mileage': '215448',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.0265575712500343',
#   'Age of Vehicle': '8',
#   'Mileage': '41430',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.826605059027082',
#   'Age of Vehicle': '22',
#   'Mileage': '40397',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.810823880864115',
#   'Age of Vehicle': '3',
#   'Mileage': '207932',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.235649168430272',
#   'Age of Vehicle': '8',
#   'Mileage': '129189',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.3311342387618454',
#   'Age of Vehicle': '3',
#   'Mileage': '25247',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.8025081887300116',
#   'Age of Vehicle': '11',
#   'Mileage': '151015',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.2259106918876554',
#   'Age of Vehicle': '3',
#   'Mileage': '170532',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.447994426812644',
#   'Age of Vehicle': '24',
#   'Mileage': '41986',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.6813622827676808',
#   'Age of Vehicle': '29',
#   'Mileage': '211980',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.695366564783421',
#   'Age of Vehicle': '23',
#   'Mileage': '67008',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.668004825636061',
#   'Age of Vehicle': '19',
#   'Mileage': '158027',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.41935494270986',
#   'Age of Vehicle': '13',
#   'Mileage': '70408',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.7643180844646977',
#   'Age of Vehicle': '23',
#   'Mileage': '224155',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.3053177676079963',
#   'Age of Vehicle': '23',
#   'Mileage': '144763',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.9980375788356826',
#   'Age of Vehicle': '6',
#   'Mileage': '266897',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.948280020542169',
#   'Age of Vehicle': '25',
#   'Mileage': '1833',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.528436879229925',
#   'Age of Vehicle': '12',
#   'Mileage': '235304',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.4953141922914313',
#   'Age of Vehicle': '21',
#   'Mileage': '270789',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.362339974025368',
#   'Age of Vehicle': '7',
#   'Mileage': '236192',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.651996812321864',
#   'Age of Vehicle': '22',
#   'Mileage': '40024',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.4244818531753936',
#   'Age of Vehicle': '4',
#   'Mileage': '248140',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.452917236732969',
#   'Age of Vehicle': '11',
#   'Mileage': '108853',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.6693539863427267',
#   'Age of Vehicle': '12',
#   'Mileage': '211670',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.3266775901753656',
#   'Age of Vehicle': '28',
#   'Mileage': '140707',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.008678008488271',
#   'Age of Vehicle': '19',
#   'Mileage': '151136',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.01258965233174',
#   'Age of Vehicle': '13',
#   'Mileage': '9940',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.308776056616539',
#   'Age of Vehicle': '27',
#   'Mileage': '297313',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.548850873293651',
#   'Age of Vehicle': '17',
#   'Mileage': '240739',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.458980474076877',
#   'Age of Vehicle': '26',
#   'Mileage': '45200',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.4078847323734385',
#   'Age of Vehicle': '23',
#   'Mileage': '187401',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.951134930627231',
#   'Age of Vehicle': '24',
#   'Mileage': '160811',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.179812440044379',
#   'Age of Vehicle': '19',
#   'Mileage': '239354',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.450227761740058',
#   'Age of Vehicle': '3',
#   'Mileage': '148865',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.938121881067725',
#   'Age of Vehicle': '20',
#   'Mileage': '83682',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.428027777451344',
#   'Age of Vehicle': '17',
#   'Mileage': '33677',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.5575748156279863',
#   'Age of Vehicle': '6',
#   'Mileage': '285166',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.753031353727709',
#   'Age of Vehicle': '14',
#   'Mileage': '158337',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.2887060871725189',
#   'Age of Vehicle': '20',
#   'Mileage': '530',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
# ...
#   'Mileage': '274823',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.050706521039893',
#   'Age of Vehicle': '27',
#   'Mileage': '192863',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.577450228828955',
#   'Age of Vehicle': '18',
#   'Mileage': '27429',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.149001853842721',
#   'Age of Vehicle': '26',
#   'Mileage': '280217',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.7744005224697883',
#   'Age of Vehicle': '15',
#   'Mileage': '70207',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.8695337010770006',
#   'Age of Vehicle': '19',
#   'Mileage': '30365',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.1939309322789566',
#   'Age of Vehicle': '24',
#   'Mileage': '242975',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.045574320815497',
#   'Age of Vehicle': '18',
#   'Mileage': '106657',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.9289405913944506',
#   'Age of Vehicle': '0',
#   'Mileage': '7784',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.6706453404302977',
#   'Age of Vehicle': '18',
#   'Mileage': '130229',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.0678579515036466',
#   'Age of Vehicle': '6',
#   'Mileage': '232273',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.331221949617972',
#   'Age of Vehicle': '28',
#   'Mileage': '251428',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.731957196203215',
#   'Age of Vehicle': '22',
#   'Mileage': '120913',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.770750129630756',
#   'Age of Vehicle': '10',
#   'Mileage': '143363',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.5285885139855533',
#   'Age of Vehicle': '4',
#   'Mileage': '288298',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.316033474669147',
#   'Age of Vehicle': '29',
#   'Mileage': '257946',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.3346422308974715',
#   'Age of Vehicle': '16',
#   'Mileage': '287794',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.451671579849275',
#   'Age of Vehicle': '10',
#   'Mileage': '199813',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.959247330926039',
#   'Age of Vehicle': '23',
#   'Mileage': '233420',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.0111102232400144',
#   'Age of Vehicle': '25',
#   'Mileage': '95830',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '0.9168404032646105',
#   'Age of Vehicle': '7',
#   'Mileage': '298345',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.19712226880172',
#   'Age of Vehicle': '9',
#   'Mileage': '72920',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.616497916236508',
#   'Age of Vehicle': '11',
#   'Mileage': '213869',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.094086743095966',
#   'Age of Vehicle': '9',
#   'Mileage': '162806',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.1410159642526523',
#   'Age of Vehicle': '12',
#   'Mileage': '219999',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.5246515851786855',
#   'Age of Vehicle': '25',
#   'Mileage': '81451',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.141637231356356',
#   'Age of Vehicle': '17',
#   'Mileage': '236889',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.918891339658471',
#   'Age of Vehicle': '9',
#   'Mileage': '99978',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.533588947973967',
#   'Age of Vehicle': '18',
#   'Mileage': '42568',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.6927322864111782',
#   'Age of Vehicle': '19',
#   'Mileage': '248586',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.2159980979007186',
#   'Age of Vehicle': '16',
#   'Mileage': '156865',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '0.8956315180468271',
#   'Age of Vehicle': '19',
#   'Mileage': '180537',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.554353794114594',
#   'Age of Vehicle': '15',
#   'Mileage': '221913',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.412305631028734',
#   'Age of Vehicle': '4',
#   'Mileage': '192455',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.797885672674119',
#   'Age of Vehicle': '2',
#   'Mileage': '16767',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.225087147573471',
#   'Age of Vehicle': '29',
#   'Mileage': '84244',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.6817256130821256',
#   'Age of Vehicle': '26',
#   'Mileage': '26440',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.187386019429694',
#   'Age of Vehicle': '14',
#   'Mileage': '217838',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.114657379277449',
#   'Age of Vehicle': '25',
#   'Mileage': '226262',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.8733906131551368',
#   'Age of Vehicle': '1',
#   'Mileage': '55919',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '0.8571783090240985',
#   'Age of Vehicle': '12',
#   'Mileage': '147683',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.5118052763577978',
#   'Age of Vehicle': '21',
#   'Mileage': '194555',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.4800969376101465',
#   'Age of Vehicle': '7',
#   'Mileage': '98995',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.344228403325079',
#   'Age of Vehicle': '22',
#   'Mileage': '159353',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.9065481312856036',
#   'Age of Vehicle': '26',
#   'Mileage': '147525',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.9226876742549974',
#   'Age of Vehicle': '29',
#   'Mileage': '19507',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.258190707640528',
#   'Age of Vehicle': '16',
#   'Mileage': '210468',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.711930648841938',
#   'Age of Vehicle': '3',
#   'Mileage': '217716',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.554942118809791',
#   'Age of Vehicle': '18',
#   'Mileage': '275337',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.9776067294387802',
#   'Age of Vehicle': '21',
#   'Mileage': '238143',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.792320346897387',
#   'Age of Vehicle': '24',
#   'Mileage': '212521',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.498372067470755',
#   'Age of Vehicle': '8',
#   'Mileage': '161764',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.0442230272302864',
#   'Age of Vehicle': '22',
#   'Mileage': '33512',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.664673517531613',
#   'Age of Vehicle': '14',
#   'Mileage': '141791',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.637774805417126',
#   'Age of Vehicle': '27',
#   'Mileage': '186499',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '1.2305530732106578',
#   'Age of Vehicle': '8',
#   'Mileage': '12402',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.9363909692252186',
#   'Age of Vehicle': '23',
#   'Mileage': '119764',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.075815370342869',
#   'Age of Vehicle': '20',
#   'Mileage': '140288',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '2.8243371930182786',
#   'Age of Vehicle': '8',
#   'Mileage': '245739',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.301207431207639',
#   'Age of Vehicle': '13',
#   'Mileage': '31050',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '2.6494981256177357',
#   'Age of Vehicle': '22',
#   'Mileage': '95808',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.539038706958077',
#   'Age of Vehicle': '20',
#   'Mileage': '50093',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.3450329212405103',
#   'Age of Vehicle': '15',
#   'Mileage': '5050',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.7453041295438654',
#   'Age of Vehicle': '23',
#   'Mileage': '115455',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.275462091435318',
#   'Age of Vehicle': '22',
#   'Mileage': '47431',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.251090059885771',
#   'Age of Vehicle': '24',
#   'Mileage': '243445',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '5.671514644488742',
#   'Age of Vehicle': '25',
#   'Mileage': '278904',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.6093749054933015',
#   'Age of Vehicle': '16',
#   'Mileage': '147545',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.9176899686719353',
#   'Age of Vehicle': '12',
#   'Mileage': '43815',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '0.9621523023186803',
#   'Age of Vehicle': '8',
#   'Mileage': '193532',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.1637730303590903',
#   'Age of Vehicle': '14',
#   'Mileage': '87986',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '3.8944052396413253',
#   'Age of Vehicle': '6',
#   'Mileage': '25634',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.0674142301181018',
#   'Age of Vehicle': '0',
#   'Mileage': '46573',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.3811044854464294',
#   'Age of Vehicle': '0',
#   'Mileage': '223784',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.903582814367824',
#   'Age of Vehicle': '4',
#   'Mileage': '127099',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.5380682322481967',
#   'Age of Vehicle': '23',
#   'Mileage': '272440',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '4.808743459478274',
#   'Age of Vehicle': '8',
#   'Mileage': '284103',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.3543109162956135',
#   'Age of Vehicle': '11',
#   'Mileage': '14570',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '1.1907164650262057',
#   'Age of Vehicle': '5',
#   'Mileage': '297567',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.586581532258737',
#   'Age of Vehicle': '27',
#   'Mileage': '80263',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.376554844272232',
#   'Age of Vehicle': '12',
#   'Mileage': '166857',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '4.379692461424227',
#   'Age of Vehicle': '25',
#   'Mileage': '112446',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '3.0611021607394804',
#   'Age of Vehicle': '27',
#   'Mileage': '193878',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.0812905728433555',
#   'Age of Vehicle': '7',
#   'Mileage': '34341',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '5.059332051905838',
#   'Age of Vehicle': '14',
#   'Mileage': '5597',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '4.956962570638692',
#   'Age of Vehicle': '5',
#   'Mileage': '134868',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '4.412421648443019',
#   'Age of Vehicle': '26',
#   'Mileage': '107127',
#   'Emission Level': 'Medium'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Electric',
#   'Engine Size': '2.215154713595806',
#   'Age of Vehicle': '5',
#   'Mileage': '75589',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Truck',
#   'Fuel Type': 'Diesel',
#   'Engine Size': '3.8691994677192527',
#   'Age of Vehicle': '3',
#   'Mileage': '246992',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '2.6770642640881395',
#   'Age of Vehicle': '10',
#   'Mileage': '131607',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '1.2762267812984978',
#   'Age of Vehicle': '20',
#   'Mileage': '195984',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Car',
#   'Fuel Type': 'Electric',
#   'Engine Size': '5.570030592403662',
#   'Age of Vehicle': '29',
#   'Mileage': '45785',
#   'Emission Level': 'Low'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '1.5114568807785993',
#   'Age of Vehicle': '17',
#   'Mileage': '253138',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Motorcycle',
#   'Fuel Type': 'Petrol',
#   'Engine Size': '5.741234239868173',
#   'Age of Vehicle': '2',
#   'Mileage': '161941',
#   'Emission Level': 'High'},
#  {'Vehicle Type': 'Bus',
#   'Fuel Type': 'Hybrid',
#   'Engine Size': '3.1192300193813702',
#   'Age of Vehicle': '2',
#   'Mileage': '196166',
#   'Emission Level': 'Medium'},
#  ...]

# %%
# label encoding
def label_encode(value, encoding_map):
    return encoding_map.get(value, None)

for row in data:
    row['Vehicle Type'] = label_encode(row['Vehicle Type'], vehicle_type_map)
    row['Fuel Type'] = label_encode(row['Fuel Type'], fuel_type_map)

# normalisasi kolom
normalisasi_kolom = ['Engine Size', 'Age of Vehicle', 'Mileage', 'Vehicle Type', 'Fuel Type']

for column in normalisasi_kolom:
    col_values = [float(row[column]) for row in data]
    min_val, max_val = min(col_values), max(col_values)
    for row in data:
        row[column] = (float(row[column]) - min_val) / (max_val - min_val)

nama_kolom = {col: col.lower().replace(' ', '_') for col in kolom}
data = [
    {nama_kolom[key]: value for key, value in row.items()}
    for row in data
]

with open(prepared_file_path, 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=list(nama_kolom.values()))
    writer.writeheader()
    writer.writerows(data)

data
# Out:
# [{'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.3746386134092265,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.9713982662179336,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.9509822237862713,
#   'age_of_vehicle': 0.10344827586206896,
#   'mileage': 0.6282108156247186,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.732197544922115,
#   'age_of_vehicle': 0.5862068965517241,
#   'mileage': 0.9385871577381448,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.598822880295374,
#   'age_of_vehicle': 0.13793103448275862,
#   'mileage': 0.504541254873969,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.15605287922072456,
#   'age_of_vehicle': 0.5172413793103449,
#   'mileage': 0.3060435546868485,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.1560287520220239,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.24040466033147992,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.05808905335630445,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.5650068210548786,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.8664192048820101,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.9894332020266371,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.6012801301783322,
#   'age_of_vehicle': 0.6206896551724138,
#   'mileage': 0.300720129950268,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.7082691468797103,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.1285593731967566,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.02057890894674554,
#   'age_of_vehicle': 0.27586206896551724,
#   'mileage': 0.7650288352173231,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.9701834139484204,
#   'age_of_vehicle': 0.1724137931034483,
#   'mileage': 0.3650148262048585,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.8326757806409296,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.07517169378967135,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.2123899103730141,
#   'age_of_vehicle': 0.6206896551724138,
#   'mileage': 0.7518703699379934,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.1818667942817867,
#   'age_of_vehicle': 0.3793103448275862,
#   'mileage': 0.3662656308892054,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.18344680138933062,
#   'age_of_vehicle': 0.10344827586206896,
#   'mileage': 0.5792126267899015,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.30432006657806077,
#   'age_of_vehicle': 0.5172413793103449,
#   'mileage': 0.6236512156153792,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.5248990969866223,
#   'age_of_vehicle': 0.8275862068965517,
#   'mileage': 0.7235755002384867,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.43206039299467286,
#   'age_of_vehicle': 0.3448275862068966,
#   'mileage': 0.7659761112982686,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.2913031373409214,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.44073687405564244,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.612021170609529,
#   'age_of_vehicle': 0.10344827586206896,
#   'mileage': 0.14536685267522106,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.13952324035340247,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.5672916242782857,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.29221891488140894,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.8915102048984846,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.36645793305073826,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.05055585760172378,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.45619245246525075,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.8479788664040533,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.7853952025653241,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.8169622457114076,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.19972085763974237,
#   'age_of_vehicle': 0.3448275862068966,
#   'mileage': 0.7170446320466166,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.5143740097979023,
#   'age_of_vehicle': 0.3448275862068966,
#   'mileage': 0.49432801769138146,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.5925771289501379,
#   'age_of_vehicle': 0.7931034482758621,
#   'mileage': 0.4704893481473081,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.046452433190141716,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.6581500765492467,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.607711861017609,
#   'age_of_vehicle': 0.7931034482758621,
#   'mileage': 0.09970747847782073,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.1705626277725821,
#   'age_of_vehicle': 0.1724137931034483,
#   'mileage': 0.8105748031233427,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.0650590830935667,
#   'age_of_vehicle': 0.6896551724137931,
#   'mileage': 0.8272321860396855,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.9491529168839435,
#   'age_of_vehicle': 0.6896551724137931,
#   'mileage': 0.7152067830304162,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.9659043369772321,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.6948136634568239,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.8086234174889584,
#   'age_of_vehicle': 1.0,
#   'mileage': 0.9589502579993129,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.3046917020383996,
#   'age_of_vehicle': 0.3103448275862069,
#   'mileage': 0.4847385151113883,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.09768919611063485,
#   'age_of_vehicle': 0.8620689655172413,
#   'mileage': 0.47637313338247605,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.6844225856256394,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.6170703152361352,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.4402702814830407,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.15506309058827847,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.12206248175588819,
#   'age_of_vehicle': 0.20689655172413793,
#   'mileage': 0.5370621766669891,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.49531087766923204,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.012381298635455477,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.034386994811369594,
#   'age_of_vehicle': 0.9310344827586207,
#   'mileage': 0.8792056222836692,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.9095761476641648,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.02650371739152188,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.2588444371356946,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.25139839963709987,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.6627054594691518,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.04616970250861387,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.31179109590269094,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.26931992915442265,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.5202093079149094,
#   'age_of_vehicle': 0.5172413793103449,
#   'mileage': 0.7146030613027714,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.546859400180656,
#   'age_of_vehicle': 0.27586206896551724,
#   'mileage': 0.42247846114333554,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.18489717341491543,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.1123622864042534,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.969858093919431,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.6989629995296974,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.7753491113696972,
#   'age_of_vehicle': 0.3793103448275862,
#   'mileage': 0.8122992458481623,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.9397635610859739,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.5817142361585954,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.8950788343615133,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.4363073577334752,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.5980641518725006,
#   'age_of_vehicle': 0.8275862068965517,
#   'mileage': 0.5081235594899385,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.9221336720368142,
#   'age_of_vehicle': 0.9655172413793104,
#   'mileage': 0.574819800738475,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.08850688491047909,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.05607607560864156,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.19602885259329997,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.7696551448098277,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.04522894972368466,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.8811268582788261,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.32541435528988955,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.48295069828256176,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.388779941256857,
#   'age_of_vehicle': 0.0,
#   'mileage': 0.6579132575290103,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.2714171832124827,
#   'age_of_vehicle': 0.8620689655172413,
#   'mileage': 0.6164899418625983,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.8289695595062273,
#   'age_of_vehicle': 0.9310344827586207,
#   'mileage': 0.21085231498930979,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.35684659108643063,
#   'age_of_vehicle': 0.6206896551724138,
#   'mileage': 0.25859636366062166,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.28100547971569506,
#   'age_of_vehicle': 0.3448275862068966,
#   'mileage': 0.413902944227453,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.5428440236296344,
#   'age_of_vehicle': 0.13793103448275862,
#   'mileage': 0.051940081452401046,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.14095402527176007,
#   'age_of_vehicle': 0.0,
#   'mileage': 0.8654267578809034,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.8024212269214852,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.4645688726413993,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.0745609269640426,
#   'age_of_vehicle': 1.0,
#   'mileage': 0.915749131941549,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.9871654904631063,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.8669377299395945,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.7724602080789841,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.011410674200402258,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.19876247528807087,
#   'age_of_vehicle': 0.1724137931034483,
#   'mileage': 0.8815337867361336,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.005512102714048653,
#   'age_of_vehicle': 0.9655172413793104,
#   'mileage': 0.3795441734182324,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.8156895750053768,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.8136701277822066,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.7070535555942816,
#   'age_of_vehicle': 0.3793103448275862,
#   'mileage': 0.9137144896550113,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.7292098928971185,
#   'age_of_vehicle': 0.0,
#   'mileage': 0.7859623024145533,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.7714854989413423,
#   'age_of_vehicle': 0.06896551724137931,
#   'mileage': 0.44636049191646626,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.07405478623248904,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.8748061252739262,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.35855949646529583,
#   'age_of_vehicle': 0.8620689655172413,
#   'mileage': 0.08225958700097062,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.11589149240314231,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.6244617370508361,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.8633455814558102,
#   'age_of_vehicle': 0.3448275862068966,
#   'mileage': 0.5211052443738805,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.6234697681612645,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.9357553359327834,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.3309836865480737,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.4344027991341096,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.06356540130941893,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.4903888168054782,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.3110621272402432,
#   'age_of_vehicle': 0.9655172413793104,
#   'mileage': 0.7508030166073507,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.32526730332576087,
#   'age_of_vehicle': 0.06896551724137931,
#   'mileage': 0.2560447221045539,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.7298090793319197,
#   'age_of_vehicle': 0.20689655172413793,
#   'mileage': 0.7528009686231476,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.6377333056193474,
#   'age_of_vehicle': 0.9310344827586207,
#   'mileage': 0.27076752710910684,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.8874619874506822,
#   'age_of_vehicle': 0.6206896551724138,
#   'mileage': 0.4310306297051103,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.4723421407962735,
#   'age_of_vehicle': 0.10344827586206896,
#   'mileage': 0.9045485929281171,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.11961777419958594,
#   'age_of_vehicle': 0.8275862068965517,
#   'mileage': 0.7819864112579092,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.7134428771840216,
#   'age_of_vehicle': 0.5172413793103449,
#   'mileage': 0.42117762427161476,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.7609971176923324,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.28025696531435224,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.5614306017787029,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.31480585843559356,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.7711822430644144,
#   'age_of_vehicle': 0.6206896551724138,
#   'mileage': 0.2652172897897648,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.4939291577499351,
#   'age_of_vehicle': 0.13793103448275862,
#   'mileage': 0.3088653700547352,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.5228748997003703,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.6600279513153462,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.4276550977240366,
#   'age_of_vehicle': 0.13793103448275862,
#   'mileage': 0.5751566841334592,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.02541496300859561,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.5216622693933097,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.10791151406516036,
#   'age_of_vehicle': 0.7931034482758621,
#   'mileage': 0.12921312711177524,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.031426789196493665,
#   'age_of_vehicle': 0.10344827586206896,
#   'mileage': 0.17134022888057984,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.6365859082372944,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.19127638780949077,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.31443677861838487,
#   'age_of_vehicle': 0.8620689655172413,
#   'mileage': 0.6911746556951639,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.5087085971359636,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.7960688042640766,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.9078217037725719,
#   'age_of_vehicle': 1.0,
#   'mileage': 0.6788066989763415,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.2493538948307929,
#   'age_of_vehicle': 0.5172413793103449,
#   'mileage': 0.3170739842632093,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.4104919570990818,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.8727481346332807,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.7557616685981757,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.697345292137942,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.22885380493699575,
#   'age_of_vehicle': 0.6206896551724138,
#   'mileage': 0.6247152334668636,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.07699090743369384,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.10177214007678273,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.289825015545793,
#   'age_of_vehicle': 0.13793103448275862,
#   'mileage': 0.903914851888048,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.16125705585970337,
#   'age_of_vehicle': 0.8275862068965517,
#   'mileage': 0.5454942679790665,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.9299593898157665,
#   'age_of_vehicle': 0.5862068965517241,
#   'mileage': 0.7671935611910329,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.8083463674948909,
#   'age_of_vehicle': 0.9310344827586207,
#   'mileage': 0.8437127885606407,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.6335783693833973,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.0076682665848362445,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.8717052031746172,
#   'age_of_vehicle': 0.6896551724137931,
#   'mileage': 0.32145013291884444,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.8038967568154956,
#   'age_of_vehicle': 0.5862068965517241,
#   'mileage': 0.6195619181673543,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.18661328124500334,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.3705550570867258,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.8928098154197003,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.9345212086442278,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.5394891961970355,
#   'age_of_vehicle': 0.4827586206896552,
#   'mileage': 0.5851130894208607,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.8076659430759746,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.20590579939761247,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.8963431555190627,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.1716871187130387,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.31808534505187147,
#   'age_of_vehicle': 0.5172413793103449,
#   'mileage': 0.37616533303091654,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.11007264688931283,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.34529547342123434,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.22799054822310305,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.6117235421454469,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.42722174060144674,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.13048728015022998,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.8182436632765765,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.38974073320502856,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.860972041107152,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.13008368717208071,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.006942536614087861,
#   'age_of_vehicle': 0.06896551724137931,
#   'mileage': 0.221359074337824,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.510885848576859,
#   'age_of_vehicle': 0.4827586206896552,
#   'mileage': 0.5491799724489421,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.41752210380448557,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.6945735089574293,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.22216148263120591,
#   'age_of_vehicle': 0.6206896551724138,
#   'mileage': 0.22859372863208663,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.11988897531764618,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.9041316580333347,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.3377028082619435,
#   'age_of_vehicle': 0.13793103448275862,
#   'mileage': 0.9459018635322057,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.9431753263618371,
#   'age_of_vehicle': 0.8620689655172413,
#   'mileage': 0.033204695020463165,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.3232863309902308,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.5972342206819721,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.5189315328638333,
#   'age_of_vehicle': 0.1724137931034483,
#   'mileage': 0.0025282932019599275,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.703214041972777,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.9413989666685568,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.3637248887266154,
#   'age_of_vehicle': 0.10344827586206896,
#   'mileage': 0.01257142094747621,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.9720561950328659,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.16781462741030062,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.9627186623791986,
#   'age_of_vehicle': 0.6206896551724138,
#   'mileage': 0.25175863138619176,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.2518446937061791,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.2879652576490876,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.49738308259875297,
#   'age_of_vehicle': 0.20689655172413793,
#   'mileage': 0.7467037127218511,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.30095514427778935,
#   'age_of_vehicle': 0.10344827586206896,
#   'mileage': 0.3502920212003055,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.2849126129524087,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.6872187774134694,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.03688615570769294,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.5987885539697205,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.6097319369205478,
#   'age_of_vehicle': 0.20689655172413793,
#   'mileage': 0.8452804637650222,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.5028151967674912,
#   'age_of_vehicle': 0.06896551724137931,
#   'mileage': 0.19293412095114523,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.051482250292558776,
#   'age_of_vehicle': 0.4827586206896552,
#   'mileage': 0.7131187730773464,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.2787167614699476,
#   'age_of_vehicle': 0.0,
#   'mileage': 0.9495742260854483,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.90852132147378,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.47261404837111876,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.23962069516321566,
#   'age_of_vehicle': 0.3103448275862069,
#   'mileage': 0.8681084831241432,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.14492583994869843,
#   'age_of_vehicle': 0.5172413793103449,
#   'mileage': 0.7300496652846664,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.4895850446612413,
#   'age_of_vehicle': 0.8275862068965517,
#   'mileage': 0.4112612447341123,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.9859286443881004,
#   'age_of_vehicle': 0.9310344827586207,
#   'mileage': 0.5480459095351343,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.24211480918116485,
#   'age_of_vehicle': 0.4827586206896552,
#   'mileage': 0.4281687885873245,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.6723215492809378,
#   'age_of_vehicle': 0.7931034482758621,
#   'mileage': 0.418252409049822,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.761831929806748,
#   'age_of_vehicle': 0.4827586206896552,
#   'mileage': 0.6828359577995177,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.23769578263852903,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.4909825320956482,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.728418840929192,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.7349795034805725,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.3678796404034819,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.20453491746356822,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.6324801206237343,
#   'age_of_vehicle': 0.1724137931034483,
#   'mileage': 0.1504467874332487,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.6337043606704523,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.5537629208123893,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.5359205893232234,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.4955187837508797,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.09030468139586412,
#   'age_of_vehicle': 0.5862068965517241,
#   'mileage': 0.0431310809954404,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.8355364763640638,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.0172877884772537,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.3208627515022242,
#   'age_of_vehicle': 0.6206896551724138,
#   'mileage': 0.14919264726974354,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.18656171760109724,
#   'age_of_vehicle': 1.0,
#   'mileage': 0.0777233353457391,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.0407754932232945,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.6252889358820841,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.5910550558454911,
#   'age_of_vehicle': 0.5172413793103449,
#   'mileage': 0.7322577524874336,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.6777519600488696,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.531822138909365,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.01658106836770886,
#   'age_of_vehicle': 0.20689655172413793,
#   'mileage': 0.030152731590656654,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.5122320000152288,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.1585219824753925,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.226550737630262,
#   'age_of_vehicle': 0.9310344827586207,
#   'mileage': 0.6284409636866384,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.6453508639422206,
#   'age_of_vehicle': 0.3793103448275862,
#   'mileage': 0.33834433485542365,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.17440606291212257,
#   'age_of_vehicle': 0.27586206896551724,
#   'mileage': 0.8784818233063271,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.6911292687223651,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.6188181063150627,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.3868374268435215,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.07953783600783171,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.9369937940537331,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.442911606466827,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.13754974371538267,
#   'age_of_vehicle': 0.0,
#   'mileage': 0.6139616486606383,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.34115500272072924,
#   'age_of_vehicle': 0.3103448275862069,
#   'mileage': 0.42275197043431273,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.11349524971558057,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.7855720513530371,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.9249538843260082,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.02387202433565594,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.877585695005899,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.9240244557331884,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.25800583673462735,
#   'age_of_vehicle': 0.10344827586206896,
#   'mileage': 0.08938750596216899,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.660166474785681,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.003302124366675895,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.8174508645030069,
#   'age_of_vehicle': 0.5862068965517241,
#   'mileage': 0.9239177204001241,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.5553524290600864,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.7008842355248543,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.5297946828239964,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.3137985437297995,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.24191176888409213,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.23748278058884548,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.09311850630345903,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.708829346879826,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.8974679441934277,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.7343324205238704,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.9006711850328146,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.8234630945908534,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.6332759812557834,
#   'age_of_vehicle': 0.8275862068965517,
#   'mileage': 0.7862758374554296,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.33911784387296345,
#   'age_of_vehicle': 1.0,
#   'mileage': 0.9087179418759402,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.34930062078098445,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.9049521859062664,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.7261575064423637,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.8305076265730954,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.8973624151712115,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.16673393216302487,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.8873356319958379,
#   'age_of_vehicle': 0.4827586206896552,
#   'mileage': 0.28332894161910827,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.7800932284538347,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.67716230775132,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.6422087960401617,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.9776823089520925,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.0841530679991924,
#   'age_of_vehicle': 0.27586206896551724,
#   'mileage': 0.1931542625755903,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.16166460250332287,
#   'age_of_vehicle': 0.06896551724137931,
#   'mileage': 0.7818696694873702,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.8988067683298901,
#   'age_of_vehicle': 0.06896551724137931,
#   'mileage': 0.2325496069137812,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.606595740679386,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.9791199004693019,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.00918811781387557,
#   'age_of_vehicle': 0.0,
#   'mileage': 0.3031150039858976,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.10148974218439083,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.5193507823366366,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.6636852322386686,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.5876947502893528,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.0050514340178181615,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.38263616259793803,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.1608436985120644,
#   'age_of_vehicle': 0.6206896551724138,
#   'mileage': 0.7091962495872345,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.5488835052128516,
#   'age_of_vehicle': 1.0,
#   'mileage': 0.707745316153392,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.692087009851582,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.6036249987491953,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.6521413291705067,
#   'age_of_vehicle': 0.4827586206896552,
#   'mileage': 0.2675187704089631,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.22432361720529156,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.18616976921819703,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.712376997981146,
#   'age_of_vehicle': 0.8275862068965517,
#   'mileage': 0.639391341763201,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.23730721191810958,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.4026490375474889,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.3254837430832306,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.20225344971931944,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.7466992711774905,
#   'age_of_vehicle': 0.20689655172413793,
#   'mileage': 0.9790331780111872,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.6498122840655999,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.24929704776739703,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.8494614846849088,
#   'age_of_vehicle': 0.5862068965517241,
#   'mileage': 0.7005540230881867,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.6577946238190504,
#   'age_of_vehicle': 0.1724137931034483,
#   'mileage': 0.9269029742467654,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.5684640751148339,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.746470229180773,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.09369067452106221,
#   'age_of_vehicle': 0.6896551724137931,
#   'mileage': 0.6375134669971014,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.3678122909455166,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.26119136644574675,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.26526871170659483,
#   'age_of_vehicle': 0.9310344827586207,
#   'mileage': 0.3597247562598605,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.24404974984674893,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.3832332133672663,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.9732850282939818,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.06477834073253794,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.39320167605379297,
#   'age_of_vehicle': 0.0,
#   'mileage': 0.9279803340148829,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.8922972214239518,
#   'age_of_vehicle': 0.5172413793103449,
#   'mileage': 0.7262472190442518,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.6313125728133478,
#   'age_of_vehicle': 0.20689655172413793,
#   'mileage': 0.08669910976061267,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.7950333779661606,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.04141664470809554,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.5027732543143567,
#   'age_of_vehicle': 0.7931034482758621,
#   'mileage': 0.7113276207693616,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.5770618838302036,
#   'age_of_vehicle': 0.3448275862068966,
#   'mileage': 0.7689146684366943,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.4926508794398381,
#   'age_of_vehicle': 0.4827586206896552,
#   'mileage': 0.045555974343494315,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.19528876041361476,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.7098533389814113,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.7226529126180798,
#   'age_of_vehicle': 1.0,
#   'mileage': 0.32331466576831097,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.2808432847901115,
#   'age_of_vehicle': 0.7931034482758621,
#   'mileage': 0.891320082586464,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.02431147831397216,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.32707375077966827,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.6456504575089037,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.10493417431881177,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.17715112025526975,
#   'age_of_vehicle': 0.7931034482758621,
#   'mileage': 0.1502399877254367,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.9407234860556535,
#   'age_of_vehicle': 0.1724137931034483,
#   'mileage': 0.04380151230625035,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.9541974395284858,
#   'age_of_vehicle': 0.27586206896551724,
#   'mileage': 0.7918060618998222,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.9151217660039465,
#   'age_of_vehicle': 0.9310344827586207,
#   'mileage': 0.3702948897123816,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.37025590647033746,
#   'age_of_vehicle': 0.20689655172413793,
#   'mileage': 0.018358477287054673,
#   'emission_level': 'Low'},
# ...
#   'mileage': 0.47799751173254795,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.14014273757612697,
#   'age_of_vehicle': 0.13793103448275862,
#   'mileage': 0.9614251835347407,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.8687117089128409,
#   'age_of_vehicle': 1.0,
#   'mileage': 0.8601867201232793,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.4875628881971068,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.9597441020389784,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.8948036299284564,
#   'age_of_vehicle': 0.3448275862068966,
#   'mileage': 0.6662853102162392,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.8000788135354803,
#   'age_of_vehicle': 0.7931034482758621,
#   'mileage': 0.7783807582878318,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.4253268994341305,
#   'age_of_vehicle': 0.8620689655172413,
#   'mileage': 0.3194521809030476,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.02246427719668129,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.9949367426377637,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.26874472522385606,
#   'age_of_vehicle': 0.3103448275862069,
#   'mileage': 0.24303635338734586,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.5417818428920425,
#   'age_of_vehicle': 0.3793103448275862,
#   'mileage': 0.7131688052647203,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.6336528545949032,
#   'age_of_vehicle': 0.3103448275862069,
#   'mileage': 0.5428492330065675,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.2579518785910589,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.7336152925048448,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.1393854132583294,
#   'age_of_vehicle': 0.8620689655172413,
#   'mileage': 0.27149132608644894,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.8351641081122065,
#   'age_of_vehicle': 0.5862068965517241,
#   'mileage': 0.7899515354878305,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.9846800039288678,
#   'age_of_vehicle': 0.3103448275862069,
#   'mileage': 0.3332877484515038,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.5258331222245016,
#   'age_of_vehicle': 0.6206896551724138,
#   'mileage': 0.1417978899758845,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.1717181296066109,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.82896663520198,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.2723757597425209,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.523033151327354,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.018384446110890424,
#   'age_of_vehicle': 0.6551724137931034,
#   'mileage': 0.6019906139616487,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.9145560160353048,
#   'age_of_vehicle': 0.5172413793103449,
#   'mileage': 0.7399993996137515,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.11777406917318702,
#   'age_of_vehicle': 0.13793103448275862,
#   'mileage': 0.6417428545697732,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.5766743608012592,
#   'age_of_vehicle': 0.06896551724137931,
#   'mileage': 0.05573919221365745,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.27412416787498134,
#   'age_of_vehicle': 1.0,
#   'mileage': 0.2808073193754649,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.554329319221546,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.08800328211149172,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.65160029897774,
#   'age_of_vehicle': 0.4827586206896552,
#   'mileage': 0.7264073220438482,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.8299741493722126,
#   'age_of_vehicle': 0.8620689655172413,
#   'mileage': 0.7545053984730177,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.20647033132718756,
#   'age_of_vehicle': 0.034482758620689655,
#   'mileage': 0.18632987221779346,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.010987423782352502,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.4924067816962246,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.13691424282542136,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.648747360802116,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.9002716522703516,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.33000897243893573,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.8741354049350947,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.531331823473101,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.5975771320666662,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.4918797759892197,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.6006818029836354,
#   'age_of_vehicle': 1.0,
#   'mileage': 0.06487840510728568,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.6652205890126013,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.7018248406474832,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.17541120800450882,
#   'age_of_vehicle': 0.10344827586206896,
#   'mileage': 0.7260003935865407,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.914669188668159,
#   'age_of_vehicle': 0.6206896551724138,
#   'mileage': 0.9181940381645526,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.4188820253123042,
#   'age_of_vehicle': 0.7241379310344828,
#   'mileage': 0.7941342263522866,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.3832395511556582,
#   'age_of_vehicle': 0.8275862068965517,
#   'mileage': 0.7086725793593879,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.5190586537719536,
#   'age_of_vehicle': 0.27586206896551724,
#   'mileage': 0.5393736637236622,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.0469681388427904,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.1115917907186957,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.16632062585625415,
#   'age_of_vehicle': 0.4827586206896552,
#   'mileage': 0.4727541384957656,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.7382389954907658,
#   'age_of_vehicle': 0.9310344827586207,
#   'mileage': 0.6218767407031858,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.08281137652367265,
#   'age_of_vehicle': 0.27586206896551724,
#   'mileage': 0.04117982568785919,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.6033178269058354,
#   'age_of_vehicle': 0.7931034482758621,
#   'mileage': 0.3992835390768061,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.24540961589720844,
#   'age_of_vehicle': 0.6896551724137931,
#   'mileage': 0.4677409133209031,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.389398447426334,
#   'age_of_vehicle': 0.27586206896551724,
#   'mileage': 0.8194705260384181,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.2887669883835056,
#   'age_of_vehicle': 0.4482758620689655,
#   'mileage': 0.10337984103106332,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.3557656631066134,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.31937880036156596,
#   'emission_level': 'Low'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.7192457009518726,
#   'age_of_vehicle': 0.6896551724137931,
#   'mileage': 0.16689737064177954,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.297197445465531,
#   'age_of_vehicle': 0.5172413793103449,
#   'mileage': 0.016657382916342847,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.5665595522199111,
#   'age_of_vehicle': 0.7931034482758621,
#   'mileage': 0.38491095938387027,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.4761787456474228,
#   'age_of_vehicle': 0.7586206896551724,
#   'mileage': 0.15801832512249547,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.6638546783038752,
#   'age_of_vehicle': 0.8275862068965517,
#   'mileage': 0.8118189368493731,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.9370935739732082,
#   'age_of_vehicle': 0.8620689655172413,
#   'mileage': 0.9300916923220606,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.7327758703263457,
#   'age_of_vehicle': 0.5517241379310345,
#   'mileage': 0.4919464855723849,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.21499194318288248,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.1459572324862328,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.031180666220372404,
#   'age_of_vehicle': 0.27586206896551724,
#   'mileage': 0.6453351656232176,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.26232952431685097,
#   'age_of_vehicle': 0.4827586206896552,
#   'mileage': 0.29328868238566813,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.5952412739443271,
#   'age_of_vehicle': 0.20689655172413793,
#   'mileage': 0.0853148859099354,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.05142929696058047,
#   'age_of_vehicle': 0.0,
#   'mileage': 0.1551564840047097,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.4965005644812815,
#   'age_of_vehicle': 0.0,
#   'mileage': 0.7462400811188531,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.5970067111314709,
#   'age_of_vehicle': 0.13793103448275862,
#   'mileage': 0.423749278702632,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.33433053635727267,
#   'age_of_vehicle': 0.7931034482758621,
#   'mileage': 0.9085311550430777,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.7711272506900362,
#   'age_of_vehicle': 0.27586206896551724,
#   'mileage': 0.9474328484658464,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.0,
#   'engine_size': 0.10661795995055964,
#   'age_of_vehicle': 0.3793103448275862,
#   'mileage': 0.04841114450296357,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.07514823766679761,
#   'age_of_vehicle': 0.1724137931034483,
#   'mileage': 0.9923417398526385,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.7283912404074457,
#   'age_of_vehicle': 0.9310344827586207,
#   'mileage': 0.2675287768464379,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 1.0,
#   'engine_size': 0.4956253762146149,
#   'age_of_vehicle': 0.41379310344827586,
#   'mileage': 0.5563612590766727,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.6885931815357197,
#   'age_of_vehicle': 0.8620689655172413,
#   'mileage': 0.37487450259667054,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.4349435604964582,
#   'age_of_vehicle': 0.9310344827586207,
#   'mileage': 0.6464892414119751,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.2464628490649638,
#   'age_of_vehicle': 0.2413793103448276,
#   'mileage': 0.11435690294089197,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 1.0,
#   'engine_size': 0.8193315348206004,
#   'age_of_vehicle': 0.4827586206896552,
#   'mileage': 0.018481890015910236,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.7996393073592629,
#   'age_of_vehicle': 0.1724137931034483,
#   'mileage': 0.44966261628314214,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.6948891067218285,
#   'age_of_vehicle': 0.896551724137931,
#   'mileage': 0.3571330889538937,
#   'emission_level': 'Medium'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.0,
#   'engine_size': 0.27221352276169336,
#   'age_of_vehicle': 0.1724137931034483,
#   'mileage': 0.2519387472607377,
#   'emission_level': 'High'},
#  {'vehicle_type': 1.0,
#   'fuel_type': 1.0,
#   'engine_size': 0.5903925847853703,
#   'age_of_vehicle': 0.10344827586206896,
#   'mileage': 0.823649881423716,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.36106840238271964,
#   'age_of_vehicle': 0.3448275862068966,
#   'mileage': 0.43878561874806127,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.09159736466716369,
#   'age_of_vehicle': 0.6896551724137931,
#   'mileage': 0.6535137605192674,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.3333333333333333,
#   'fuel_type': 0.0,
#   'engine_size': 0.9175716714235372,
#   'age_of_vehicle': 1.0,
#   'mileage': 0.152528126428002,
#   'emission_level': 'Low'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.13684722397461563,
#   'age_of_vehicle': 0.5862068965517241,
#   'mileage': 0.8441497363303725,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.0,
#   'fuel_type': 0.6666666666666666,
#   'engine_size': 0.9505051309502465,
#   'age_of_vehicle': 0.06896551724137931,
#   'mileage': 0.539964043534674,
#   'emission_level': 'High'},
#  {'vehicle_type': 0.6666666666666666,
#   'fuel_type': 0.3333333333333333,
#   'engine_size': 0.4461252818459043,
#   'age_of_vehicle': 0.06896551724137931,
#   'mileage': 0.6541208177260704,
#   'emission_level': 'Medium'},
#  ...]

# %%
import csv

# File path for prepared data
prepared_file_path = 'vehicle_dataset_clean.csv'

# Count categories in Emission Level
category_counts = {
    "Low": 0,
    "Medium": 0,
    "High": 0
}

# Read the prepared dataset and count emission levels
with open(prepared_file_path, 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        emission_level = row['emission_level']
        if emission_level in category_counts:
            category_counts[emission_level] += 1

print("Emission Level Counts:")
for category, count in category_counts.items():
    print(f"{category}: {count}")
# Out:
# Emission Level Counts:
# Low: 2305
# Medium: 3274
# High: 4421
